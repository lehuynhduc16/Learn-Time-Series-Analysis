# %% [markdown]
# # Time Series Analysis
# ## Web Scraping Stock Data

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import yfinance as yf

# %% [markdown]
# ### Lấy dữ liệu chứng khoán của Tesla, chuyển vào DataFrame df

# %%
start = dt.datetime(2010,1,1)
end = dt.datetime(2024,1,1)
yf.pdr_override()
y_symbols = ['TSLA']
df = pdr.get_data_yahoo(y_symbols, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Chuyển dữ liệu từ df vào file csv

# %%
print(df.head(2))
df.to_csv('tesla.csv')
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500

# %% [markdown]
# ### Đọc dữ liệu từ file csv để xử lý

# %%
df = pd.read_csv('tesla.csv')
df.head(2)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1  2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500

# %% [markdown]
# ### Không lấy index

# %%
df = pd.read_csv('tesla.csv', parse_dates = True, index_col = 0)
df.head(3)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000

# %% [markdown]
# ### Biểu diễn giá cổ phiếu qua biểu đồ

# %%
df.plot()
plt.show()

# %% [markdown]
# ### Giá mở cửa và giá đóng của của TSLA từ 2023/1/1 - 2023/4/2 (Y/M/D)

# %%
df23 = pdr.get_data_yahoo('TSLA', '2023-1-1', '2023-4-3')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df23[['Open', 'Close']].plot()
plt.show()

# %% [markdown]
# ### New

# %%
df['100ma'] = df['Adj Close'].rolling(window = 100).mean()

# %%
df.dropna(inplace = True)
print(df.head)
# Out:
# <bound method NDFrame.head of                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-11-17    2.013333    2.050000    1.907333    1.966000    1.966000
# 2010-11-18    2.044667    2.049333    1.928000    1.992667    1.992667
# 2010-11-19    2.010667    2.091333    1.980000    2.066000    2.066000
# 2010-11-22    2.104667    2.230000    2.100000    2.226667    2.226667
# 2010-11-23    2.219333    2.378667    2.146000    2.304667    2.304667
# ...                ...         ...         ...         ...         ...
# 2023-03-27  194.419998  197.389999  189.940002  191.809998  191.809998
# 2023-03-28  192.000000  192.350006  185.429993  189.190002  189.190002
# 2023-03-29  193.130005  195.289993  189.440002  193.880005  193.880005
# 2023-03-30  195.580002  197.330002  194.419998  195.279999  195.279999
# 2023-03-31  197.529999  207.789993  197.199997  207.460007  207.460007
#
#                Volume       100ma
# Date
# 2010-11-17   11250000    1.399193
# ...

# %%
df.plot()
plt.show()

# %%
ax1 = plt.subplot2grid((6, 1), (0, 0), rowspan = 5, colspan = 1)
#ax2 = plt.subplot2grid((6, 1), (5, 0), rowspan = 1, colspan = 0)

ax1.plot(df.index, df["Adj Close"])
ax1.plot(df.index, df["100ma"])
#ax2.bar(df.index, df["Volume"])
plt.show()

# %%
fb_stoke = pd.read_csv('META.csv', parse_dates = True, index_col = 0)

# %%
fb_stoke.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  338.299988  341.079987  337.190002  338.540009  338.540009
# 2022-01-04  339.950012  343.089996  331.869995  336.529999  336.529999
# 2022-01-05  333.019989  335.760010  323.839996  324.170013  324.170013
# 2022-01-06  322.820007  339.170013  322.720001  332.459991  332.459991
# 2022-01-07  332.739990  337.000000  328.880005  331.790009  331.790009
#
#               Volume
# Date
# 2022-01-03  14537900
# 2022-01-04  15998000
# 2022-01-05  20564500
# 2022-01-06  27962800
# 2022-01-07  14722000

# %%
fb_stoke['Open']["2022-06-01":].plot()
plt.show()
